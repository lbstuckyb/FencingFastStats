# %%
import numpy as np
import pandas as pd

# %%
cc = pd.read_excel('Listado competencias.xlsx') # era listado 3

# %%
listado = cc['id'].unique()

# %%
df = pd.read_html('https://sistemainfo.fedesgrimacolombia.com/prueba_stats?prueba=1377',encoding='utf_8')

# %%
df[3]
# Out:
#   Cuadro    ID                       Deportista  TD  TR  DIF Resultado  \
# 0      8  1007      MEJIA PINZON JUAN SEBASTIAN   4  14  -10         D
# 1      8   111           LEON LIZARAZO SANTIAGO  14   4   10         V
# 2      8  2697       AVELLA DE LA ROSA JERONIMO  14  15   -1         D
# 3      8   212  FONSECA RAMIREZ NICOLAS ORLANDO  15  14    1         V
# 4   semi  1320         SUAREZ ZAMUDIO JUAN JOSE  10  15   -5         D
# 5   semi   111           LEON LIZARAZO SANTIAGO  15  10    5         V
# 6   semi   212  FONSECA RAMIREZ NICOLAS ORLANDO  13  14   -1         D
# 7   semi   944      CASTILLO CARDONA JUAN DAVID  14  13    1         V
# 8  final   111           LEON LIZARAZO SANTIAGO  15  13    2         V
# 9  final   944      CASTILLO CARDONA JUAN DAVID  13  15   -2         D
#
#    ID oponente                         Oponente
# 0          111           LEON LIZARAZO SANTIAGO
# 1         1007      MEJIA PINZON JUAN SEBASTIAN
# ...

# %%
#RESULTADOS M15

results = pd.DataFrame()
cc=[1433,1434,1435,1436,1437,1438, #III Torneo Nal Infantil, Precadete, Cadete y Juvenil
    1373,1374,1375,1376,1377,1378, #II Escalafón Nal Infantil,Precadete,Cadete y Juvenil -Bogotá, 24 al 26 Enero 2020.
    1331,1332,1333,1334,1335,1336, #I Escal Nal Infantil,Precadete, Cadete y Juvenil - Bogotá, 6 al 8 Dic 2019
    1265,1266,1267,1268,1269,1270, #Gran Campeonato Nal  16 al 18 de Agosto
    1166,1167,1168,1169,1170,1171, #III Escalafón Nacional Infantil Precadete, Cadete y Juvenil Individual y por equipos
    1090,1091,1092,1093,1094,1095, #II Escalafón Nacional Infantil Precadete, Cadete y Juvenil
    949,950,951,952,953,954, #I Escalafón Nacional Infantil,Precadete, Cadete y Juvenil, CAR-Coliseo 3, Calle 63#59A-06 Bogotá
    821,822,823,824,825,826, # Gran Campeonato Nacional Infantil, del 7 al 9 de Diciembre de 2018
    754,755,756,757,758,759, #V ESCALAFON NACIONAL INFANTIL Y VI ESCALAFÒN M15, CADETES JUVENIL (EQUIPOS)
    706,707,708,709,710,711, #V Escalafón Nacional M15,Cadete y Juvenil
    637,638,639,640,641,642, #IV Escalafón Nacional Infantil M15, Cadete y Juvenil Equipos
    588,589,590,591,592,593, #III Escalafón Nacional Infantil M15, Cadete y Juvenil Equipos
    517,518,519,520,521,522, #II ESCALAFON NACIONAL INFANTIL, M15, CADETE Y JUVENIL INDIVIDUAL Y POR EQUIPOS
    457,458,459,460,461,462, #I Escalafón Nacional Infantil, M15, Cadetes y Juvenil individual y por equipos
    386,387,388,389,390,391, #GRAN CAMPEONATO NACIONAL INFANTIL M15, CADETES, JUVENIL INDIVIDUAL Y EQUIPOS
    186,187,188,189,190,191, #V ESCALAFÓN NACIONAL CATEGORIA M15, CADETE Y JUVENIL, INDIVIDUAL Y POR EQUIPOS
    136,137,138,139,140,142, #IV ESCALAFON NACIONAL INFANTIL, M15, CADETES Y JUVENIL a
    87,86,100,82,79,80, #III ESCALAFÓN NACIONAL M15, CADETE Y JUVENIL INDIVIDUAL Y EQUIPOS MIXTOS JUVENILES
    228,212,252,244,220,236, #II ESCALAFÓN NACIONAL INFANTIL, M15, CADETE Y JUVENIL INDIVIDUAL Y EQUIPOS JUVENILES
    266,260,272,284,290,278, #I ESCALAFÓN NACIONAL INFANTIL, M15, CADETE Y JUVENIL INDIVIDUAL Y EQUIPOS JUVENILES
    ] 

for e in cc:
    df = pd.read_html('https://sistemainfo.fedesgrimacolombia.com/prueba_stats?prueba={}'.format(e),encoding='utf-8')
    df = df[0][:5]
    results= pd.concat(objs=[results,df],ignore_index=True,sort=False)

# %%
# RESULTADOS CADETES
results = pd.DataFrame()
cc=[1439,1440,1441,1442,1443,1444, #III Torneo Nal Infantil, Precadete, Cadete y Juvenil
    1379,1380,1381,1382,1383,1384, #II Escalafón Nal Infantil,Precadete,Cadete y Juvenil -Bogotá, 24 al 26 Enero 2020.
    1338,1339,1340,1341,1342,1343, #I Escal Nal Infantil,Precadete, Cadete y Juvenil - Bogotá, 6 al 8 Dic 2019
    1271,1272,1273,1274,1275,1276, #Gran Campeonato Nal , 16 al 18 de Agosto
    1160,1161,1162,1163,1164,1165, #III Escalafón Nacional Infantil Precadete, Cadete y Juvenil Individual y por equipos
    1096,1097,1098,1099,1100,1101, # II Escalafón Nacional Infantil Precadete, Cadete y Juvenil
    955,956,957,958,959,960, #I Escalafón Nacional Infantil,Precadete, Cadete y Juvenil, CAR-Coliseo 3, Calle 63#59A-06 Bogotá
    827,828,829,830,831,832, #Gran Campeonato Nacional del 7 al 9 de Diciembre de 2018
    760,761,762,763,764,765, #V ESCALAFON NACIONAL INFANTIL Y VI ESCALAFÒN M15, CADETES JUVENIL (EQUIPOS)
    694,695,696,697,698,699, #V Escalafón Nacional M15,Cadete y Juvenil
    625,626,627,628,629,630, #IV Escalafón Nacional Infantil M15, Cadete y Juvenil Equipos
    594,595,596,597,598,599, #III Escalafón Nacional Infantil M15, Cadete y Juvenil Equipos
    523,524,525,526,527,528, #II ESCALAFON NACIONAL INFANTIL, M15, CADETE Y JUVENIL INDIVIDUAL Y POR EQUIPOS
    463,464,465,466,467,468, #I Escalafón Nacional Infantil, M15, Cadetes y Juvenil individual y por equipos
    392,393,394,395,396,397, #GRAN CAMPEONATO NACIONAL INFANTIL M15, CADETES, JUVENIL INDIVIDUAL Y EQUIPOS
    192,193,194,195,196,197, #V ESCALAFÓN NACIONAL CATEGORIA M15, CADETE Y JUVENIL, INDIVIDUAL Y POR EQUIPOS
    141,143,145,146,148,150, #IV ESCALAFON NACIONAL INFANTIL, M15, CADETES Y JUVENIL a
    81,83,84,85,88,89, #III ESCALAFÓN NACIONAL M15, CADETE Y JUVENIL INDIVIDUAL Y EQUIPOS MIXTOS JUVENILES
    221,253,237,245,229,213, #II ESCALAFÓN NACIONAL INFANTIL, M15, CADETE Y JUVENIL INDIVIDUAL Y EQUIPOS JUVENILES
    279,273,285,261,291,267, #I ESCALAFÓN NACIONAL INFANTIL, M15, CADETE Y JUVENIL INDIVIDUAL Y EQUIPOS JUVENILES
    ] 

for e in cc:
    df = pd.read_html('https://sistemainfo.fedesgrimacolombia.com/prueba_stats?prueba={}'.format(e),encoding='utf-8')
    df = df[0][:5]
    results= pd.concat(objs=[results,df],ignore_index=True,sort=False)

# %%
results.to_csv('D:\\Desktop\\resultadosCAD.csv',encoding='latin-1')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-54-acf1b3b41a17> in <module>
# ----> 1 results.to_csv('D:\\Desktop\\resultadosCAD.csv',encoding='latin-1')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     200                 self.writer = UnicodeWriter(f, **writer_kwargs)
#     201
# --> 202             self._save()
#     203
#     204         finally:
#
# ...

# %%
results = pd.DataFrame()
match = pd.DataFrame()
ccc =[396] 
for e in ccc:
    df = pd.read_html('https://sistemainfo.fedesgrimacolombia.com/prueba_stats?prueba={}'.format(e),encoding='utf_8')
    fin = df[0]
    p = df[1]
    pm = df[2]
    t = df[3]
    fin['comp_id']=e

# -------------------------------------- combates ------------------------------------

    #poule = pm.copy()
    #tablas = t.copy()
    #info = fin.copy()

    #poule.drop(axis=1,columns=['Poule','Match'],inplace=True)
    #poule['Cuadro'] = 'poule'
    #poule['DIF'] = poule['TD']-poule['TR']
    #poule.rename(columns={"ID": "id"},inplace=True)
    #tablas.rename(columns={"ID": "id"},inplace=True)
    
    #poule = pd.merge(left=poule,right=info,on=['id'],how='outer')
    #tablas = pd.merge(left=tablas,right=info,on=['id'],how='outer')

    #combates =pd.concat(objs=[poule,tablas],ignore_index=True,sort=False)
    #combates = pd.merge(left=combates,right=info,on=['id'],how='outer')
    
    #match = pd.concat(objs=[match,combates],ignore_index=True,sort=False)

     
# -------------------------------------- resultados ----------------------------------

    #------------------------ merge final + poule results ----------------------------
    p.columns = ['Poule', 'id', 'Deportista', 'poule_order', 'poule_vict', 'td_polues',
                 'tr_poules', 'poule_ind', 'p_diff', 'rank_poule', 'p_matches']
    p.drop(axis=1,columns=['Deportista'],inplace=True)
    comp = pd.merge(left=fin,right=p,on=['id'],how='outer')

    # ------------------------merge poule match results ------------------------------
    a = []
    for i in pm['Asalto #'].unique():
        i='pm{}'.format(i)
        a.append(i)
    
    for i in a:
        x = int(i[2])
        i= pm[pm['Asalto #']==x].copy()
        i.columns = ['Poule', 'Match', 'id', 'name', 'Asalto #', 'p{}_td'.format(x), 'p{}_tr'.format(x),
                      'p{}_result'.format(x), 'p{}_opp_id'.format(x), 'p{}_opp'.format(x)]
        i.drop(axis=1,columns=['Poule','Match','Asalto #','name',],inplace=True)
        comp = pd.merge(left=comp,right=i,on=['id'],how='outer')

    #----------------------- merge table results -------------------------------------
    t.columns = ['Cuadro', 'id', 'Deportista', 'TD', 'TR', 'DIF', 'Resultado',
                  'ID oponente', 'Oponente']
    t.drop(axis=1,columns=['Deportista',],inplace=True)

    b = []
    for i in t['Cuadro'].unique():
        i='t{}'.format(i)
        b.append(i)

    for i in b:
        x = i[1:]
        i= t[t['Cuadro']==x].copy()
        if len(x)<4:
            i.columns = ['Cuadro', 'id', 'td_t{}'.format(x), 'tr_t{}'.format(x), 'match_dif_t{}'.format(x),
                         'match_res_t{}'.format(x),'t{}_opp_id'.format(x),'t{}_opp'.format(x)]
        elif len(x)>=4:
            i.columns = ['Cuadro', 'id', 'td_{}'.format(x), 'tr_{}'.format(x), 'match_dif_{}'.format(x),
                         'match_res_{}'.format(x),'{}_opp_id'.format(x),'{}_opp'.format(x)]
        i.drop(axis=1,columns=['Cuadro'],inplace=True)
        comp = pd.merge(left=comp,right=i,on=['id'],how='outer')
        
    results= pd.concat(objs=[results,comp],ignore_index=True,sort=False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-56-c3e75ded768b> in <module>
#       5     df = pd.read_html('https://sistemainfo.fedesgrimacolombia.com/prueba_stats?prueba={}'.format(e),encoding='utf_8')
#       6     fin = df[0]
# ----> 7     p = df[1]
#       8     pm = df[2]
#       9     t = df[3]
#
# IndexError: list index out of range

# %%
results[]
# Out:
#      final_pos  points                               name   age   country  \
# 0          1.0    64.0    VAN ERVEN GARCIA SASKIA LORETTA  32.0  COLOMBIA
# 1          2.0    52.0     PRIETO ALJURE TATIANA CATALINA  31.0  COLOMBIA
# 2          3.0    40.0        GUERRA ACOSTA LAURA JULIETH  22.0  COLOMBIA
# 3          3.0    40.0    ORJUELA MENDOZA ANGELA CRISTINA  27.0  COLOMBIA
# 4          5.0    28.0               SERNA CAMERO VANESSA  33.0  COLOMBIA
# ..         ...     ...                                ...   ...       ...
# 241       20.0     8.0        FERNANDEZ DIOSA LIZ MAYERCY  28.0  COLOMBIA
# 242       21.0     8.0         CORREA SANTA CARMEN ANDREA  15.0  COLOMBIA
# 243       22.0     8.0       ROJAS LOPEZ SOPHIA ALEJANDRA  18.0  COLOMBIA
# 244       23.0     8.0  MARTINEZ HINCAPIE MARIA ALEJANDRA  25.0  COLOMBIA
# 245        NaN     NaN                                NaN   NaN       NaN
#
#           liga                       club    id  \
# ...

# %%
df = pd.read_html('https://sistemainfo.fedesgrimacolombia.com/prueba_stats?prueba=989',encoding='utf_8')

# %%
df[2]
# Out:
#     Poule  Match    ID                          Deportista  Asalto #  TD  TR  \
# 0    1-R1      1   803                   MENDEZ PAEZ DANNA         1   0   5
# 1    1-R1      1   472           GUALTERO MOSQUERA JUANITA         1   5   0
# 2    1-R1      2   101          VARGAS LEóN CAROLINA MARíA         1   5   0
# 3    1-R1      2  1278      ESCOBAR SUáREZ ANDREA CAROLINA         1   0   5
# 4    1-R1      3   803                   MENDEZ PAEZ DANNA         2   0   5
# ..    ...    ...   ...                                 ...       ...  ..  ..
# 115  3-R2      8   472           GUALTERO MOSQUERA JUANITA         3   2   5
# 116  3-R2      9   629      SANCHEZ MONTOYA MARIA FERNANDA         4   0   5
# 117  3-R2      9   428                SERNA CAMERO VANESSA         4   5   0
# 118  3-R2     10  1609  SANTAMARIA TRUJILLO MANUELA ISABEL         4   0   5
# 119  3-R2     10   472           GUALTERO MOSQUERA JUANITA         4   5   0
#
# ...

# %%
results = pd.DataFrame()
match = pd.DataFrame()
ccc = np.array([1398,1399,1400,1401,1402])
for e in listado[:6]:
    df = pd.read_html('https://sistemainfo.fedesgrimacolombia.com/prueba_stats?prueba={}'.format(e),encoding='utf_8')
    fin = df[0]
    p = df[1]
    pm = df[2]
    t = df[3]
    fin['comp_id']=e
    pm['comp_id']=e
    t['comp_id']=e

# -------------------------------------- combates ------------------------------------

    poule = pm.copy()
    tablas = t.copy()

    #poule.drop(axis=1,columns=['Poule','Match'],inplace=True)
    poule['Cuadro'] = 'poule'
    poule['DIF'] = poule['TD']-poule['TR']
    poule.rename(columns={"ID": "id"},inplace=True)
    tablas.rename(columns={"ID": "id"},inplace=True)

    combates =pd.concat(objs=[poule,tablas],ignore_index=True,sort=False)
    #combates = pd.merge(left=combates,right=info,on=['id'],how='outer')
    
    match = pd.concat(objs=[match,combates],ignore_index=True,sort=False)

     
# -------------------------------------- resultados ----------------------------------

    #------------------------ merge final + poule results ----------------------------
    p.columns = ['Poule', 'id', 'Deportista', 'poule_order', 'poule_vict', 'td_polues',
                 'tr_poules', 'poule_ind', 'p_diff', 'rank_poule', 'p_matches']
    p.drop(axis=1,columns=['Deportista'],inplace=True)
    comp = pd.merge(left=fin,right=p,on=['id'],how='outer')

        
    results= pd.concat(objs=[results,comp],ignore_index=True,sort=False)

# %%
match[match['Cuadro']=='final'].groupby('Deportista').count()
# Out:
#                                  Poule  Match  id  Asalto #  TD  TR  \
# Deportista
# ARENAS GOMEZ DIEGO SEBASTIAN         0      0   1         0   1   1
# BAQUERO HERRERA JUAN FELIPE          0      0   1         0   1   1
# CASTILLO GUTIERREZ JUAN ANDRES       0      0   1         0   1   1
# HERNÁNDEZ VÁSQUEZ ALEJANDRO          0      0   1         0   1   1
# IBAÑEZ VILLALBA ADRIANA YINNETH      0      0   1         0   1   1
# JURADO SOSSA DANIEL                  0      0   1         0   1   1
# KLIMAVICIUS PALMA LINDA              0      0   1         0   1   1
# ORJUELA MENDOZA ANGELA CRISTINA      0      0   1         0   1   1
# PACHECO CORTES JUAN SEBASTIAN        0      0   1         0   1   1
# PACHÓN NIÑO SANTIAGO                 0      0   1         0   1   1
# PINEDA VALENCIA JULIANA              0      0   1         0   1   1
# REYES ALVAREZ MANUEL ALEJANDRO       0      0   1         0   1   1
#
# ...

# %%
match.drop_duplicates(inplace=True)

# %%
match.to_csv('C:\\Users\\User\\python\\tbl_comp_nles\\matchnales.csv',encoding='latin-1')
results.to_csv('C:\\Users\\User\\python\\tbl_comp_nles\\resnales.csv',encoding='latin-1')

# %%
rsts.to_csv('C:\\Users\\User\\python\\rankings_csv\\tblrsts3.csv',encoding='latin-1')

# %%
df = pd.read_html('https://sistemainfo.fedesgrimacolombia.com/prueba_stats?prueba={}'.format(e),encoding='utf_8')
fin = df[0]
p = df[1]
pm = df[2]
t = df[3]

# %%
fin
# Out:
#    final_pos  points                             name  age   country  \
# 0          2      26  GALINDO ALTAMIRANO MARIA KARINA   11      PERÚ
# 1          3      20  RODRIGUEZ SANTAMARIA MARIA JOSE   11  COLOMBIA
#
#            liga                          club    id  \
# 0          PERU                      peruclub  2824
# 1  CUNDINAMARCA  CLUB DE ESGRIMA FUSA FENCING  1008
#
#                                          competition  \
# 0  II Escalafón Nal Infantil,Precadete,Cadete y J...
# 1  II Escalafón Nal Infantil,Precadete,Cadete y J...
#
#                                                place        date category  \
# 0  Centro alto Rendimiento CAR Coliseo3 Cll 63#59...  24-01-2020      M13
# 1  Centro alto Rendimiento CAR Coliseo3 Cll 63#59...  24-01-2020      M13
#
#   weapon gender event type
# 0      S      F     I  NAL
# 1      S      F     I  NAL

# %%
df = pd.read_html('https://sistemainfo.fedesgrimacolombia.com/prueba_stats?prueba=687',encoding='utf_8')

# %%
df
# Out:
# [    final_pos  points                                    name  age   country  \
#  0           1      64                      DYNER VILLA KARINA   18  COLOMBIA
#  1           2      52                   SALAZAR ALDANA SUSANA   23  COLOMBIA
#  2           3      40        CASTILLO GUTIERREZ LAURA MARIELA   21  COLOMBIA
#  3           3      40                 TOVAR KARAINDROS ORIANA   22  COLOMBIA
#  4           5      28            LOZANO OLARTE LASKMI NATALIA   32  COLOMBIA
#  5           6      28            RAMOS RENGIFO MARIA VICTORIA   26  COLOMBIA
#  6           7      28  JARAMILLO QUEVEDO MARIA DE LOS ANGELES   18  COLOMBIA
#  7           8      28              TAMAYO PACHON ANGELA MARIA   21  COLOMBIA
#  8           9      16         VAN ERVEN GARCIA SASKIA LORETTA   32  COLOMBIA
#  9          10      16                   CAICEDO GRUESO ELIANA   26  COLOMBIA
#  10         11      16        SILVA HERNANDEZ GERIZIM FERNANDA   21  COLOMBIA
# ...

# %%
fin = df[0]
p = df[1]
pm = df[2]
t = df[3]

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
import pandas as pd
import numpy as np
from dash.dependencies import Input, Output, State
import datetime as dt
import dash_table 
import dash_auth
import requests
from io import StringIO

#USERNAME_PASSWORD_PAIRS = [['fce','esgrima']]

app = dash.Dash()
app.config['suppress_callback_exceptions'] = True

app.layout = html.Div([
    html.H1('Federación Colombiana de Esgrima',style={'font-size':60,'text-align': 'center','font-style': 'bold'}),
    html.H2('Plataforma Estadística',style={'font-size':30,'text-align': 'center'}),
    html.Div([
        dcc.Tabs(id="tabs", value='tab-1', children=[
            dcc.Tab(label='Estadisticas', value='tab-1'),
            dcc.Tab(label='Mano a Mano', value='tab-2'),
            dcc.Tab(label='Rankings', value='tab-3'),
            dcc.Tab(label='Internacional', value='tab-4'),
            dcc.Tab(label='Top 10 Benchmarking', value='tab-5'),
            dcc.Tab(label='Información', value='tab-6'),
            
        ]),
    html.Div(id='tabs-content')
    ],style={'padding':40}),
    html.H3('Haz Esgrima, Descubre el Mundo',style={'font-size':10,'text-align': 'center','font-style': 'italic'})
],style={'font-family':'verdana','color':'rgb(0, 72, 132)'})



if __name__=='__main__':
    app.run_server()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [23/Mar/2020 10:43:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Mar/2020 10:43:44] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Mar/2020 10:43:44] "GET /_dash-dependencies HTTP/1.1" 200 -

# %%
for e in [1276]:
    df = pd.read_html('https://sistemainfo.fedesgrimacolombia.com/prueba_stats?prueba={}'.format(e),encoding='utf_8')
    fin = df[0]
    p = df[1]
    pm = df[2]
    t = df[3]

# %%
fin
# Out:
#     final_pos  points                              name  age   country  \
# 0           1      64              GUALTERO CRUZ SAMUEL   16  COLOMBIA
# 1           2      52     BORONDY LONDOÑO ANDRES CAMILO   17  COLOMBIA
# 2           3      40  MORALES JIMENEZ CHRISTIAN DANIEL   14  COLOMBIA
# 3           3      40           PINZON GUERRA ALEJANDRO   15  COLOMBIA
# 4           5      28       NAJAR VALENCIA DIEGO ANDRéS   17  COLOMBIA
# 5           6      28       ANDRADE VARGAS JOSE RICARDO   16  COLOMBIA
# 6           7      28                TORO NOVOA NICOLAS   16  COLOMBIA
# 7           8      28      CRUZ GARROTE MANUEL SANTIAGO   15  COLOMBIA
# 8           9      16    ORELLANO CORREA ANDRES EDUARDO   16  COLOMBIA
# 9          10      16            VELASCO VALENCIA HARRY   16  COLOMBIA
# 10         11      16              CHICA GRUESO NICOLAS   14  COLOMBIA
# 11         12      16            ARANGO LONDOñO NICOLAS   14  COLOMBIA
# ...

# %%
results = pd.DataFrame()

for e in [1275]:
    df = pd.read_html('https://sistemainfo.fedesgrimacolombia.com/prueba_stats?prueba={}'.format(e),encoding='utf_8')
    fin = df[0]
    p = df[1]
    pm = df[2]
    t = df[3]

# -------------------------------------- combates ------------------------------------

    poule = pm.copy()
    tablas = t.copy()
    info = fin.copy()

    poule.drop(axis=1,columns=['Poule','Match'],inplace=True)
    poule['Cuadro'] = 'poule'
    poule['DIF'] = poule['TD']-poule['TR']
    poule.rename(columns={"ID": "id"},inplace=True)
    tablas.rename(columns={"ID": "id"},inplace=True)

    combates =pd.concat(objs=[poule,tablas],ignore_index=True,sort=False)
    combates = pd.merge(left=combates,right=info,on=['id'],how='outer')

# -------------------------------------- resultados ----------------------------------

    #------------------------ merge final + poule results ----------------------------
    p.columns = ['Poule', 'id', 'Deportista', 'poule_order', 'poule_vict', 'td_polues',
                 'tr_poules', 'poule_ind', 'p_diff', 'rank_poule', 'p_matches']
    p.drop(axis=1,columns=['Deportista'],inplace=True)
    comp = pd.merge(left=fin,right=p,on=['id'],how='outer')

    # ------------------------merge poule match results ------------------------------
    a = []
    for i in pm['Asalto #'].unique():
        i='pm{}'.format(i)
        a.append(i)
    
    for i in a:
        x = int(i[2])
        i= pm[pm['Asalto #']==x].copy()
        i.columns = ['Poule', 'Match', 'id', 'name', 'Asalto #', 'p{}_td'.format(x), 'p{}_tr'.format(x),
                      'p{}_result'.format(x), 'p{}_opp_id'.format(x), 'p{}_opp'.format(x)]
        i.drop(axis=1,columns=['Poule','Match','Asalto #','name',],inplace=True)
        comp = pd.merge(left=comp,right=i,on=['id'],how='outer')

    #----------------------- merge table results -------------------------------------
    t.columns = ['Cuadro', 'id', 'Deportista', 'TD', 'TR', 'DIF', 'Resultado',
                  'ID oponente', 'Oponente']
    t.drop(axis=1,columns=['Deportista',],inplace=True)

    b = []
    for i in t['Cuadro'].unique():
        i='t{}'.format(i)
        b.append(i)

    for i in b:
        x = i[1:]
        i= t[t['Cuadro']==x].copy()
        if len(x)<4:
            i.columns = ['Cuadro', 'id', 'td_t{}'.format(x), 'tr_t{}'.format(x), 'match_dif_t{}'.format(x),
                         'match_res_t{}'.format(x),'t{}_opp_id'.format(x),'t{}_opp'.format(x)]
        elif len(x)>=4:
            i.columns = ['Cuadro', 'id', 'td_{}'.format(x), 'tr_{}'.format(x), 'match_dif_{}'.format(x),
                         'match_res_{}'.format(x),'{}_opp_id'.format(x),'{}_opp'.format(x)]
        i.drop(axis=1,columns=['Cuadro'],inplace=True)
        comp = pd.merge(left=comp,right=i,on=['id'],how='outer')
        
    results= pd.concat(objs=[results,comp],ignore_index=True,sort=False)
results
# Out:
#     final_pos  points                               name  age   country  \
# 0           1      64          BOLAÑOS CAMACHO ALEJANDRO   16  COLOMBIA
# 1           2      52         SANCHEZ MONTOYA JUAN DAVID   18  COLOMBIA
# 2           3      40      BONILLA CRIOLLO JOSÉ SANTIAGO   18  COLOMBIA
# 3           3      40        GIRALDO HURTADO JUAN MANUEL   17  COLOMBIA
# 4           5      28         GOMEZ PLAZAS CARLOS FELIPE   16  COLOMBIA
# 5           6      28      VILLA CASTILLO GABRIEL FELIPE   16  COLOMBIA
# 6           7      28        CASTAÑO ECHEVERRY JUAN JOSE   17  COLOMBIA
# 7           8      28               REMOLINA DIAZ THOMAS   17  COLOMBIA
# 8           9      16  GARZON RAMIREZ LUIS ANDRES FELIPE   17  COLOMBIA
# 9          10      16           BERMUDEZ GIL JUAN CAMILO   15  COLOMBIA
# 10         11      16            RUEDA TORO JUAN ESTEBAN   16  COLOMBIA
# 11         12      16         GONZALEZ QUINTANA SANTIAGO   17  COLOMBIA
# ...

# %%
df = pd.read_excel('unicos.xlsx',sheet_name='pariticipacion (2)')
#dff = pd.read_excel('unicos.xlsx',sheet_name='PARTICIPANTES')
#ff= pd.read_excel('unicos.xlsx',sheet_name='Hoja2')

# %%
df['a']= df['Nombre']+'-'+df['Evento']

# %%
df1 =df[df['año']==2018]
df2 =df[df['año']==2019]

# %%
df1['a'].value_counts()
# Out:
# SAAVEDRA CORTES DANIEL SANTIAGO-III EscalafÃ³n Nacional Infantil M15, Cadete y Juvenil Equipos                                                                                          3
# RODRIGUEZ QUEVEDO VALENTINA-Gran Campeonato Nacional Infantil, M15, Cadetes y Juvenil Individual y por Equipos a realizarse en la ciudad de BogotÃ¡, del 7 al 9 de Diciembre de 2018    3
# REINA AGUIRRE MIGUEL ANGEL-Gran Campeonato Nacional Infantil, M15, Cadetes y Juvenil Individual y por Equipos a realizarse en la ciudad de BogotÃ¡, del 7 al 9 de Diciembre de 2018     3
# TRIANA CEBALLOS VALENTINA-IV EscalafÃ³n Nacional Infantil M15, Cadete y Juvenil Equipos                                                                                                 3
# TRIANA REYES ISABELLA-Gran Campeonato Nacional Infantil, M15, Cadetes y Juvenil Individual y por Equipos a realizarse en la ciudad de BogotÃ¡, del 7 al 9 de Diciembre de 2018          3
# ...

# %%
a = df1['a'].value_counts()

# %%
a = a.reset_index()

# %%
a['name'] =a['index'].apply(lambda x:x.split('-')[0])

# %%
b = a['name'].value_counts()

# %%
e = df1[df1['Nombre'].isin(b[b==1].index)]['Nombre'].value_counts()

# %%
df1[df1['Nombre'].isin(e.index)]['Evento'].value_counts().to_csv('D://Desktop/analisis esgrima/analisis unicos\compe18-1.csv')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
b.to_csv('C:\\Users\\User\\python\\rankings_csv\\reunicos18.csv')

# %%
df2[df2['Nombre'].isin(b[b==2].index)].to_csv('D://Desktop/analisis esgrima/analisis unicos\esg19-2.csv')

# %%
.to_csv('D://Desktop/analisis esgrima/analisis unicos\esg18-1.csv')
# Out:
#   File "<ipython-input-2-de75654d8aea>", line 1
#     .to_csv('D://Desktop/analisis esgrima/analisis unicos\esg18-1.csv')
#     ^
# SyntaxError: invalid syntax

# %%
df = pd.read_excel('output.xlsx',sheet_name='Sheet1')

# %%
df[(df['año']==2019)&(df['Arma']=='ESPADA')]['Nombre'].nunique()
# Out:
# 219

# %%
results = pd.DataFrame()
match = pd.DataFrame()

for e in [827]:
    df = pd.read_html('https://sistemainfo.fedesgrimacolombia.com/prueba_stats?prueba={}'.format(e),encoding='utf_8')
    fin = df[0]
    p = df[1]
    pm = df[2]
    t = df[3]

# -------------------------------------- combates ------------------------------------

    poule = pm.copy()
    tablas = t.copy()
    info = fin.copy()

    poule.drop(axis=1,columns=['Poule','Match'],inplace=True)
    poule['Cuadro'] = 'poule'
    poule['DIF'] = poule['TD']-poule['TR']
    poule.rename(columns={"ID": "id"},inplace=True)
    tablas.rename(columns={"ID": "id"},inplace=True)

    combates =pd.concat(objs=[poule,tablas],ignore_index=True,sort=False)
    combates = pd.merge(left=combates,right=info,on=['id'],how='outer')
    
    match = pd.concat(objs=[match,combates],ignore_index=True,sort=False)

     
# -------------------------------------- resultados ----------------------------------

    #------------------------ merge final + poule results ----------------------------
    p.columns = ['Poule', 'id', 'Deportista', 'poule_order', 'poule_vict', 'td_polues',
                 'tr_poules', 'poule_ind', 'p_diff', 'rank_poule', 'p_matches']
    p.drop(axis=1,columns=['Deportista'],inplace=True)
    comp = pd.merge(left=fin,right=p,on=['id'],how='outer')

    # ------------------------merge poule match results ------------------------------
    a = []
    for i in pm['Asalto #'].unique():
        i='pm{}'.format(i)
        a.append(i)
    
    for i in a:
        x = int(i[2])
        i= pm[pm['Asalto #']==x].copy()
        i.columns = ['Poule', 'Match', 'id', 'name', 'Asalto #', 'p{}_td'.format(x), 'p{}_tr'.format(x),
                      'p{}_result'.format(x), 'p{}_opp_id'.format(x), 'p{}_opp'.format(x)]
        i.drop(axis=1,columns=['Poule','Match','Asalto #','name',],inplace=True)
        comp = pd.merge(left=comp,right=i,on=['id'],how='outer')

    #----------------------- merge table results -------------------------------------
    t.columns = ['Cuadro', 'id', 'Deportista', 'TD', 'TR', 'DIF', 'Resultado',
                  'ID oponente', 'Oponente']
    t.drop(axis=1,columns=['Deportista',],inplace=True)

    b = []
    for i in t['Cuadro'].unique():
        i='t{}'.format(i)
        b.append(i)

    for i in b:
        x = i[1:]
        i= t[t['Cuadro']==x].copy()
        if len(x)<4:
            i.columns = ['Cuadro', 'id', 'td_t{}'.format(x), 'tr_t{}'.format(x), 'match_dif_t{}'.format(x),
                         'match_res_t{}'.format(x),'t{}_opp_id'.format(x),'t{}_opp'.format(x)]
        elif len(x)>=4:
            i.columns = ['Cuadro', 'id', 'td_{}'.format(x), 'tr_{}'.format(x), 'match_dif_{}'.format(x),
                         'match_res_{}'.format(x),'{}_opp_id'.format(x),'{}_opp'.format(x)]
        i.drop(axis=1,columns=['Cuadro'],inplace=True)
        comp = pd.merge(left=comp,right=i,on=['id'],how='outer')
        
    results= pd.concat(objs=[results,comp],ignore_index=True,sort=False)

# %%
results
# Out:
#     final_pos  points                              name  age   country  \
# 0           1      64            LOMBANA MARTINEZ SIMON   17  COLOMBIA
# 1           1      64            LOMBANA MARTINEZ SIMON   17  COLOMBIA
# 2           2      52    CASTILLO GUTIERREZ JUAN ANDRES   19  COLOMBIA
# 3           3      40                LOZANO LOZANO YAIM   18  COLOMBIA
# 4           3      40        PINZÓN GUERRA JORGE ANDRÉS   17  COLOMBIA
# 5           5      28          GARZóN PALMA JUAN FELIPE   16  COLOMBIA
# 6           6      28          ARIAS RENDON JHON DEIVID   15  COLOMBIA
# 7           7      28        ROBERTO NAGLES ALEX STIVEN   17  COLOMBIA
# 8           8      28               URIBE ARCILA DANIEL   18  COLOMBIA
# 9           9      16            MARTÍNEZ GIL ALEJANDRO   18  COLOMBIA
# 10         10      16         ZAPATA ROJAS PABLO ANDRES   17  COLOMBIA
# 11         11      16     RAMIREZ MOLINA ENRIQUE ANDRES   18  COLOMBIA
# ...

# %%
df = pd.read_html('https://sistemainfo.fedesgrimacolombia.com/prueba_stats?prueba=827',encoding='utf_8')

# %%
df[2]

a = []
for i in df[2]['Asalto #'].unique():
    i='pm{}'.format(i)
    a.append(i)

# %%
df[2]['Deportista'].value_counts()
# Out:
# COLMENARES RUIZ NICOLAS ESTEBAN     10
# CASTILLO GUTIERREZ JUAN ANDRES       6
# OVIEDO GUZMAN GUSTAVO                6
# CAMELO PARRA JUAN MATEO              6
# MARTÍNEZ GIL ALEJANDRO               6
# ORTIZ BERMUDEZ JUAN SEBASTIAN        6
# VERGARA MURIEL ALEXANDER ESTEBAN     5
# GARZóN PALMA JUAN FELIPE             5
# URIBE ARCILA DANIEL                  5
# LOMBANA MARTINEZ SIMON               5
# ALVAREZ PEREZ MISHAEL HUMBERTO       5
# LUBO VINASCO JOAN SEBASTIAN          5
# RAMIREZ QUINTERO JUAN DIEGO          5
# ARIAS RENDON JHON DEIVID             5
# ZAPATA ROJAS PABLO ANDRES            5
# GODOY VELOZA NICOLAS FELIPE          5
# RAMIREZ MOLINA ENRIQUE ANDRES        5
# LOZANO LOZANO YAIM                   5
# PINZÓN GUERRA JORGE ANDRÉS           3
# RINCON MORALES JUAN FELIPE           3
# ROBERTO NAGLES ALEX STIVEN           3
# ZEA QUINTERO GERMAN ELIAS            3
# Name: Deportista, dtype: int64

# %%
df = pd.read_html('https://fie.org/athletes/4585/profile')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-1fcd13320451> in <module>
# ----> 1 df = pd.read_html('https://fie.org/athletes/4585/profile')
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1103         na_values=na_values,
#    1104         keep_default_na=keep_default_na,
# -> 1105         displayed_only=displayed_only,
#    1106     )
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     910             break
#     911     else:
# --> 912         raise_with_traceback(retained)
#     913
#     914     ret = []
#
# ~\Anaconda3\lib\site-packages\pandas\compat\__init__.py in raise_with_traceback(exc, traceback)
# ...

# %%
df
# Out:
# [    Unnamed: 0          Unnamed: 1                            Gold  \
#  0          NaN           World Cup                               2
#  1          NaN                 NaN    La Havane (CUBA), 2007-06-08
#  2          NaN                 NaN     Lobnya (RUSSIA), 2009-03-21
#  3          NaN                 NaN                             NaN
#  4          NaN  World Championship                               1
#  5          NaN                 NaN  Budapest (HUNGARY), 2019-07-15
#  6          NaN  Zone Championships                               1
#  7          NaN                 NaN    Santiago (CHILE), 2015-04-17
#  8          NaN                 NaN                             NaN
#  9          NaN                 NaN                             NaN
#  10         NaN          Grand Prix                               -
#  11         NaN                 NaN                             NaN
#  12         NaN                 NaN                             NaN
#
# ...

# %%
results = pd.DataFrame()
 
for e in listado:
    df = pd.read_html('https://sistemainfo.fedesgrimacolombia.com/prueba_stats?prueba={}'.format(e),encoding='utf_8')
    fin = df[0]
    fin['comp_id']=e
    
    results= pd.concat(objs=[results,fin],ignore_index=True,sort=False)

# %%
results.to_csv('D://Desktop/resultadosfce.csv')
